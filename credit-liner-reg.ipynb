# %%
import statsmodels.api as sm
import scipy.stats as stats
import os 
import pandas as pd
from pandas import DataFrame
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
os.chdir('C:\\Users\\Trainer\\Downloads\\historical-rainfall-data-in-bangladesh')
data=pd.read_csv("credit.csv")

# %%
data_n = pd.get_dummies(data)

# %%
data_n.head()
# Out:
#    Seniority  Time  Age  Expenses  Income  Assets  Debt  Amount  Price  \
# 0          9    60   30        73     129       0     0     800    846
# 1         17    60   58        48     131       0     0    1000   1658
# 2         10    36   46        90     200    3000     0    2000   2985
# 3          0    60   24        63     182    2500     0     900   1325
# 4          0    36   26        46     107       0     0     310    910
#
#       Finrat     ...       Marital_married  Marital_separated  Marital_single  \
# 0  94.562648     ...                     1                  0               0
# 1  60.313631     ...                     0                  0               0
# 2  67.001675     ...                     1                  0               0
# 3  67.924528     ...                     0                  0               1
# 4  34.065934     ...                     0                  0               1
#
# ...

# %%
data.head()
# Out:
#   Status  Seniority   Home  Time  Age  Marital  Records        Job  Expenses  \
# 0   good          9   rent    60   30  married   no_rec  freelance        73
# 1   good         17   rent    60   58    widow   no_rec      fixed        48
# 2    bad         10  owner    36   46  married  yes_rec  freelance        90
# 3   good          0   rent    60   24   single   no_rec      fixed        63
# 4   good          0   rent    36   26   single   no_rec      fixed        46
#
#    Income  Assets  Debt  Amount  Price     Finrat   Savings
# 0     129       0     0     800    846  94.562648  4.200000
# 1     131       0     0    1000   1658  60.313631  4.980000
# 2     200    3000     0    2000   2985  67.001675  1.980000
# 3     182    2500     0     900   1325  67.924528  7.933333
# 4     107       0     0     310    910  34.065934  7.083871

# %%
data_n.columns
# Out:
# Index(['Seniority', 'Time', 'Age', 'Expenses', 'Income', 'Assets', 'Debt',
#        'Amount', 'Price', 'Finrat', 'Savings', 'Status_bad', 'Status_good',
#        'Home_ignore', 'Home_other', 'Home_owner', 'Home_parents', 'Home_priv',
#        'Home_rent', 'Marital_divorced', 'Marital_married', 'Marital_separated',
#        'Marital_single', 'Marital_widow', 'Records_no_rec', 'Records_yes_rec',
#        'Job_fixed', 'Job_freelance', 'Job_others', 'Job_partime'],
#       dtype='object')

# %%
import statsmodels.formula.api as smf

# %%
reg=smf.ols("Status_good~Seniority+ Time+ Age+ Expenses+ Income+ Assets+ Debt+\
Amount+ Price+ Finrat+ Savings+ Status_bad+Status_good+\
Home_ignore+ Home_other+ Home_owner+ Home_parents+ Home_priv+\
Home_rent+ Marital_divorced+ Marital_married+ Marital_separated+\
Marital_single+ Marital_widow+ Records_no_rec+ Records_yes_rec+\
Job_fixed+ Job_freelance+ Job_others+ Job_partime",data=data_n)

# %%
results=reg.fit()

# %%
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:            Status_good   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 2.237e+28
# Date:                Sat, 09 Feb 2019   Prob (F-statistic):               0.00
# Time:                        11:51:58   Log-Likelihood:             1.3085e+05
# No. Observations:                4446   AIC:                        -2.617e+05
# Df Residuals:                    4420   BIC:                        -2.615e+05
# Df Model:                          25
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept             0.1911   2.47e-15   7.74e+13      0.000       0.191       0.191
# ...

# %%
reg=smf.ols("Status_good~Seniority+ Time+ Age+ Expenses+ Income+ Amount+ Price+ Finrat+ Savings",data=data_n)

# %%
results=reg.fit()

# %%
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:            Status_good   R-squared:                       0.140
# Model:                            OLS   Adj. R-squared:                  0.138
# Method:                 Least Squares   F-statistic:                     80.16
# Date:                Sat, 09 Feb 2019   Prob (F-statistic):          3.28e-138
# Time:                        12:02:53   Log-Likelihood:                -2418.1
# No. Observations:                4446   AIC:                             4856.
# Df Residuals:                    4436   BIC:                             4920.
# Df Model:                           9
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.9770      0.058     16.851      0.000       0.863       1.091
# ...
